# %% [markdown]
# <a href="https://colab.research.google.com/github/aqhsansiddik-png/Pemograman-Dasar/blob/main/2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(200):
    print("Aqhsan")
# Out:
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# Aqhsan
# ...
